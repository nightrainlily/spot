# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Audio Feature Scaling and Engineering
# - I chose to drop key and liveness because as a human curator, I would not use these as metrics of "similarity." For example, I would not want the model to classify a live version of a song and its studio version differently. The keys did not include major or minor notation(this is covered by mode) so this was also not a metric I wished the model to differentiate on.
# - I then normalized my column values to prep the dataset for clustering

# %%
playlist_features = pd.read_csv('csv_files/playlist_features.csv')
playlist_features.set_index('name', inplace=True)
playlist_features.head()
# Out:
#                          danceability  energy  key  loudness  mode  \
# name
# 849 find out                   0.4830  0.7075  9.0   -7.7135   1.0
# 848 innocence                  0.6425  0.6660  7.5   -6.0575   0.5
# 847 sick joke                  0.5200  0.3220  6.0  -10.7800   1.0
# 846 save me                    0.6520  0.6470  8.5   -7.4910   1.0
# 845 what did you expect        0.6430  0.5325  7.0   -9.1490   0.0
#
#                          speechiness  acousticness  instrumentalness  \
# name
# 849 find out                 0.04295       0.48650          0.008570
# 848 innocence                0.04825       0.12395          0.000063
# 847 sick joke                0.03780       0.77500          0.000027
# 846 save me                  0.05930       0.20260          0.026150
# 845 what did you expect      0.04580       0.29700          0.016465
#
#                          liveness  valence     tempo
# name
# 849 find out               0.1050   0.5655  118.3540
# 848 innocence              0.1145   0.6500  138.6175
# 847 sick joke              0.1260   0.3770  142.9120
# 846 save me                0.1145   0.5010  129.0055
# 845 what did you expect    0.1245   0.4820  117.8560

# %%
playlist_features.drop(['key', 'liveness'], axis=1)
# Out:
#                                    danceability  energy  loudness  mode  \
# name
# 849 find out                             0.4830  0.7075   -7.7135   1.0
# 848 innocence                            0.6425  0.6660   -6.0575   0.5
# 847 sick joke                            0.5200  0.3220  -10.7800   1.0
# 846 save me                              0.6520  0.6470   -7.4910   1.0
# 845 what did you expect                  0.6430  0.5325   -9.1490   0.0
# ...                                         ...     ...       ...   ...
# 00 think about it                        0.5310  0.3570   -8.4800   1.0
# 00 remember                              0.5140  0.4350   -8.2780   1.0
# 00 remind me                             0.4350  0.2450  -11.3150   1.0
# 00 forgetting                            0.4350  0.3810   -9.4360   1.0
# 2022 releases i missed, whoopies!        0.5740  0.5870   -7.6710   1.0
#
#                                    speechiness  acousticness  \
# name
# 849 find out                           0.04295       0.48650
# 848 innocence                          0.04825       0.12395
# 847 sick joke                          0.03780       0.77500
# 846 save me                            0.05930       0.20260
# 845 what did you expect                0.04580       0.29700
# ...                                        ...           ...
# 00 think about it                      0.03150       0.33900
# 00 remember                            0.02940       0.44900
# 00 remind me                           0.03380       0.59000
# 00 forgetting                          0.03300       0.71700
# 2022 releases i missed, whoopies!      0.03720       0.26900
#
#                                    instrumentalness  valence     tempo
# name
# 849 find out                               0.008570   0.5655  118.3540
# 848 innocence                              0.000063   0.6500  138.6175
# 847 sick joke                              0.000027   0.3770  142.9120
# 846 save me                                0.026150   0.5010  129.0055
# 845 what did you expect                    0.016465   0.4820  117.8560
# ...                                             ...      ...       ...
# 00 think about it                          0.000303   0.3030  129.7530
# 00 remember                                0.000302   0.4410  122.6760
# 00 remind me                               0.002260   0.3610   80.5910
# 00 forgetting                              0.000006   0.4610  118.3270
# 2022 releases i missed, whoopies!          0.001070   0.5000  123.3440
#
# [927 rows x 9 columns]

# %%
# pnames = playlist_features.pop('name')
for column in playlist_features.columns:
    playlist_features[column] = playlist_features[column] / playlist_features[column].abs().max()

playlist_features.head()
# Out:
#                          danceability    energy       key  loudness  mode  \
# name
# 849 find out                 0.598513  0.784368  0.818182 -0.499806   1.0
# 848 innocence                0.796159  0.738359  0.681818 -0.392503   0.5
# 847 sick joke                0.644362  0.356984  0.545455 -0.698503   1.0
# 846 save me                  0.807931  0.717295  0.772727 -0.485388   1.0
# 845 what did you expect      0.796778  0.590355  0.636364 -0.592821   0.0
#
#                          speechiness  acousticness  instrumentalness  \
# name
# 849 find out                0.146337      0.513186          0.011953
# 848 innocence               0.164395      0.130749          0.000088
# 847 sick joke               0.128790      0.817511          0.000038
# 846 save me                 0.202044      0.213713          0.036471
# 845 what did you expect     0.156048      0.313291          0.022964
#
#                          liveness   valence     tempo
# name
# 849 find out             0.323575  0.640068  0.715857
# 848 innocence            0.352851  0.735710  0.838419
# 847 sick joke            0.388290  0.426712  0.864394
# 846 save me              0.352851  0.567063  0.780281
# 845 what did you expect  0.383667  0.545557  0.712844

# %% [markdown]
# ### Genre Feature

# %%
import ast

# %%
genres = pd.read_csv('csv_files/genres.csv')
genres = genres[['name', 'genres']]
genres.head()
# Out:
#                       name                                             genres
# 0             849 find out  ['indie pop', 'modern indie folk', 'hyperpop',...
# 1            848 innocence  ['social media pop', 'alternative r&b', 'art p...
# 2            847 sick joke  ['bedroom pop', 'bubblegrunge', 'indie pop', '...
# 3              846 save me  ['experimental indie', 'art pop', 'canadian el...
# 4  845 what did you expect  ['alternative r&b', 'art pop', 'escape room', ...

# %%
genres['genres'] = genres['genres'].apply(ast.literal_eval)

# %%
all_genres = [genre for playlist_genres in genres['genres'] for genre in playlist_genres]
genre_cols = list(set(all_genres))

# %%
counted = [pd.Series(playlist_genres).value_counts().to_dict() for playlist_genres in genres['genres']]

# %%
genre_counts = genres.copy().drop('genres', axis=1).set_index('name')
genre_counts['counted'] = counted
genre_counts.head()
# Out:
#                                                                    counted
# name
# 849 find out             {'indie pop': 1, 'modern indie folk': 1, 'hype...
# 848 innocence            {'art pop': 3, 'escape room': 2, 'alternative ...
# 847 sick joke            {'bedroom pop': 1, 'bubblegrunge': 1, 'indie p...
# 846 save me              {'art pop': 3, 'metropopolis': 2, 'experimenta...
# 845 what did you expect  {'alternative r&b': 3, 'art pop': 3, 'indie so...

# %%
gc = pd.json_normalize(genre_counts['counted'])
gc = gc.fillna(0)
gc = gc.astype(int)
gc = gc.set_index(genres['name'])
gc
# Out:
#                                    indie pop  modern indie folk  hyperpop  \
# name
# 849 find out                               1                  1         1
# 848 innocence                              0                  0         0
# 847 sick joke                              1                  0         0
# 846 save me                                0                  0         0
# 845 what did you expect                    0                  0         0
# ...                                      ...                ...       ...
# 00 think about it                          3                  0         0
# 00 remember                                0                  0         0
# 00 remind me                               1                  0         0
# 00 forgetting                              1                  0         0
# 2022 releases i missed, whoopies!          2                  0         0
#
#                                    hypnagogic pop  art pop  escape room  \
# name
# 849 find out                                    1        0            0
# 848 innocence                                   1        3            2
# 847 sick joke                                   0        0            0
# 846 save me                                     1        3            0
# 845 what did you expect                         1        3            1
# ...                                           ...      ...          ...
# 00 think about it                               0        1            0
# 00 remember                                     0        0            0
# 00 remind me                                    0        2            0
# 00 forgetting                                   0        0            0
# 2022 releases i missed, whoopies!               0        4            0
#
#                                    alternative r&b  pop  social media pop  \
# name
# 849 find out                                     0    0                 0
# 848 innocence                                    2    2                 1
# 847 sick joke                                    0    0                 0
# 846 save me                                      0    1                 0
# 845 what did you expect                          3    0                 0
# ...                                            ...  ...               ...
# 00 think about it                                0    1                 0
# 00 remember                                      0    0                 0
# 00 remind me                                     0    0                 0
# 00 forgetting                                    0    0                 0
# 2022 releases i missed, whoopies!                1    1                 0
#
#                                    chillwave  ...  neo-singer-songwriter  \
# name                                          ...
# 849 find out                               0  ...                      0
# 848 innocence                              1  ...                      0
# 847 sick joke                              0  ...                      0
# 846 save me                                1  ...                      0
# 845 what did you expect                    1  ...                      0
# ...                                      ...  ...                    ...
# 00 think about it                          0  ...                      0
# 00 remember                                0  ...                      0
# 00 remind me                               0  ...                      0
# 00 forgetting                              0  ...                      0
# 2022 releases i missed, whoopies!          0  ...                      0
#
#                                    japanese chillhop  indie emo  \
# name
# 849 find out                                       0          0
# 848 innocence                                      0          0
# 847 sick joke                                      0          0
# 846 save me                                        0          0
# 845 what did you expect                            0          0
# ...                                              ...        ...
# 00 think about it                                  0          0
# 00 remember                                        0          0
# 00 remind me                                       0          0
# 00 forgetting                                      0          0
# 2022 releases i missed, whoopies!                  0          0
#
#                                    electronic trap  progressive electro house  \
# name
# 849 find out                                     0                          0
# 848 innocence                                    0                          0
# 847 sick joke                                    0                          0
# 846 save me                                      0                          0
# 845 what did you expect                          0                          0
# ...                                            ...                        ...
# 00 think about it                                0                          0
# 00 remember                                      0                          0
# 00 remind me                                     0                          0
# 00 forgetting                                    0                          0
# 2022 releases i missed, whoopies!                0                          0
#
#                                    classic girl group  dalarna indie  \
# name
# 849 find out                                        0              0
# 848 innocence                                       0              0
# 847 sick joke                                       0              0
# 846 save me                                         0              0
# 845 what did you expect                             0              0
# ...                                               ...            ...
# 00 think about it                                   0              0
# 00 remember                                         0              0
# 00 remind me                                        0              0
# 00 forgetting                                       0              0
# 2022 releases i missed, whoopies!                   0              0
#
#                                    swedish garage rock  dmv rap  malaysian pop
# name
# 849 find out                                         0        0              0
# 848 innocence                                        0        0              0
# 847 sick joke                                        0        0              0
# 846 save me                                          0        0              0
# 845 what did you expect                              0        0              0
# ...                                                ...      ...            ...
# 00 think about it                                    0        0              0
# 00 remember                                          0        0              0
# 00 remind me                                         0        0              0
# 00 forgetting                                        0        0              0
# 2022 releases i missed, whoopies!                    0        0              0
#
# [927 rows x 830 columns]

# %% [markdown]
# ### Genre Feature Scaling

# %%
gc_norm = gc.copy()
for column in gc_norm.columns:
    gc_norm[column] = gc_norm[column] / gc_norm[column].abs().max()

gc_norm
# Out:
#                                    indie pop  modern indie folk  hyperpop  \
# name
# 849 find out                        0.111111                0.5      0.25
# 848 innocence                       0.000000                0.0      0.00
# 847 sick joke                       0.111111                0.0      0.00
# 846 save me                         0.000000                0.0      0.00
# 845 what did you expect             0.000000                0.0      0.00
# ...                                      ...                ...       ...
# 00 think about it                   0.333333                0.0      0.00
# 00 remember                         0.000000                0.0      0.00
# 00 remind me                        0.111111                0.0      0.00
# 00 forgetting                       0.111111                0.0      0.00
# 2022 releases i missed, whoopies!   0.222222                0.0      0.00
#
#                                    hypnagogic pop  art pop  escape room  \
# name
# 849 find out                                  0.5    0.000          0.0
# 848 innocence                                 0.5    0.375          0.4
# 847 sick joke                                 0.0    0.000          0.0
# 846 save me                                   0.5    0.375          0.0
# 845 what did you expect                       0.5    0.375          0.2
# ...                                           ...      ...          ...
# 00 think about it                             0.0    0.125          0.0
# 00 remember                                   0.0    0.000          0.0
# 00 remind me                                  0.0    0.250          0.0
# 00 forgetting                                 0.0    0.000          0.0
# 2022 releases i missed, whoopies!             0.0    0.500          0.0
#
#                                    alternative r&b       pop  \
# name
# 849 find out                              0.000000  0.000000
# 848 innocence                             0.285714  0.285714
# 847 sick joke                             0.000000  0.000000
# 846 save me                               0.000000  0.142857
# 845 what did you expect                   0.428571  0.000000
# ...                                            ...       ...
# 00 think about it                         0.000000  0.142857
# 00 remember                               0.000000  0.000000
# 00 remind me                              0.000000  0.000000
# 00 forgetting                             0.000000  0.000000
# 2022 releases i missed, whoopies!         0.142857  0.142857
#
#                                    social media pop  chillwave  ...  \
# name                                                            ...
# 849 find out                                    0.0       0.00  ...
# 848 innocence                                   1.0       0.25  ...
# 847 sick joke                                   0.0       0.00  ...
# 846 save me                                     0.0       0.25  ...
# 845 what did you expect                         0.0       0.25  ...
# ...                                             ...        ...  ...
# 00 think about it                               0.0       0.00  ...
# 00 remember                                     0.0       0.00  ...
# 00 remind me                                    0.0       0.00  ...
# 00 forgetting                                   0.0       0.00  ...
# 2022 releases i missed, whoopies!               0.0       0.00  ...
#
#                                    neo-singer-songwriter  japanese chillhop  \
# name
# 849 find out                                         0.0                0.0
# 848 innocence                                        0.0                0.0
# 847 sick joke                                        0.0                0.0
# 846 save me                                          0.0                0.0
# 845 what did you expect                              0.0                0.0
# ...                                                  ...                ...
# 00 think about it                                    0.0                0.0
# 00 remember                                          0.0                0.0
# 00 remind me                                         0.0                0.0
# 00 forgetting                                        0.0                0.0
# 2022 releases i missed, whoopies!                    0.0                0.0
#
#                                    indie emo  electronic trap  \
# name
# 849 find out                             0.0              0.0
# 848 innocence                            0.0              0.0
# 847 sick joke                            0.0              0.0
# 846 save me                              0.0              0.0
# 845 what did you expect                  0.0              0.0
# ...                                      ...              ...
# 00 think about it                        0.0              0.0
# 00 remember                              0.0              0.0
# 00 remind me                             0.0              0.0
# 00 forgetting                            0.0              0.0
# 2022 releases i missed, whoopies!        0.0              0.0
#
#                                    progressive electro house  \
# name
# 849 find out                                             0.0
# 848 innocence                                            0.0
# 847 sick joke                                            0.0
# 846 save me                                              0.0
# 845 what did you expect                                  0.0
# ...                                                      ...
# 00 think about it                                        0.0
# 00 remember                                              0.0
# 00 remind me                                             0.0
# 00 forgetting                                            0.0
# 2022 releases i missed, whoopies!                        0.0
#
#                                    classic girl group  dalarna indie  \
# name
# 849 find out                                      0.0            0.0
# 848 innocence                                     0.0            0.0
# 847 sick joke                                     0.0            0.0
# 846 save me                                       0.0            0.0
# 845 what did you expect                           0.0            0.0
# ...                                               ...            ...
# 00 think about it                                 0.0            0.0
# 00 remember                                       0.0            0.0
# 00 remind me                                      0.0            0.0
# 00 forgetting                                     0.0            0.0
# 2022 releases i missed, whoopies!                 0.0            0.0
#
#                                    swedish garage rock  dmv rap  malaysian pop
# name
# 849 find out                                       0.0      0.0            0.0
# 848 innocence                                      0.0      0.0            0.0
# 847 sick joke                                      0.0      0.0            0.0
# 846 save me                                        0.0      0.0            0.0
# 845 what did you expect                            0.0      0.0            0.0
# ...                                                ...      ...            ...
# 00 think about it                                  0.0      0.0            0.0
# 00 remember                                        0.0      0.0            0.0
# 00 remind me                                       0.0      0.0            0.0
# 00 forgetting                                      0.0      0.0            0.0
# 2022 releases i missed, whoopies!                  0.0      0.0            0.0
#
# [927 rows x 830 columns]

# %% [markdown]
# ### Exploratory Data Analysis

# %%
from sklearn.manifold import TSNE

def make_tsne(df, title):
    tsne = TSNE(n_components=2)
    reduced_data = tsne.fit_transform(df)
    reduced = pd.DataFrame(reduced_data)

    plt.scatter(reduced[0], reduced[1])
    plt.title(title)

    return reduced

gc_reduced = make_tsne(gc, 't-SNE').set_index(genres['name'])
gc_reduced
# Out:
#                                            0          1
# name
# 849 find out                       -8.951279  -0.970366
# 848 innocence                     -20.085094   9.372239
# 847 sick joke                      -9.276312  -1.313250
# 846 save me                       -17.315151   4.613900
# 845 what did you expect           -21.586277  10.633907
# ...                                      ...        ...
# 00 think about it                  29.956966 -16.893074
# 00 remember                        26.298744 -19.865198
# 00 remind me                       33.537682 -16.997252
# 00 forgetting                      30.392614  -9.296158
# 2022 releases i missed, whoopies!   7.002952   4.667335
#
# [927 rows x 2 columns]

# %%
total_genres = pd.Series([genre for playlist_genres in genres['genres'] for genre in playlist_genres]).value_counts()
total_genres
# Out:
# indie rock           1563
# chamber pop          1452
# art pop              1348
# indie pop            1312
# singer-songwriter     965
#                      ...
# french pop              1
# big band                1
# bubblegum pop           1
# rock-and-roll           1
# malaysian pop           1
# Name: count, Length: 830, dtype: int64

# %%
def genre_filter(col_name):
    return gc[gc[col_name] >= 1]

indie_rock = genre_filter('indie rock')
chamber_pop = genre_filter('chamber pop')
art_pop = genre_filter('art pop')
indie_pop = genre_filter('indie pop')
singer_songwriter = genre_filter('singer-songwriter')

make_tsne(indie_rock, "Indie Rock t-SNE")
make_tsne(chamber_pop, "Chamber Pop t-SNE")
make_tsne(art_pop, "")
make_tsne(indie_pop, "")
make_tsne(singer_songwriter, "t_SNE")
# Out:
#              0          1
# 0    15.425756   9.893238
# 1    -6.733803  16.650507
# 2    -0.542214   4.417612
# 3     4.212784  -6.667104
# 4     3.230654  11.825906
# ..         ...        ...
# 426 -16.198189  -4.475793
# 427 -18.923941   1.503793
# 428 -18.915052  -6.785309
# 429  -8.891006  -7.266529
# 430  15.191366   4.260629
#
# [431 rows x 2 columns]

# %%
p1 = '668 thank you'
p2 = '669 like a dream to me now'

x = playlist_features.loc[[p1, p2]]

x_genres = genres.loc[genres['name'].isin([p1, p2])]['genres']
# print(x_genres)

p1_g = set(genres.loc[genres['name'].isin([p1])]['genres'].to_list()[0])
p2_g = set(genres.loc[genres['name'].isin([p2])]['genres'].to_list()[0])
print(p1_g.intersection(p2_g))

# print(set(genres.loc[genres['name'].isin(['767 summer sweat'])]['genres'].to_list()[0]))

ax = x.plot.bar(rot=0)
# Out:
# {'indie pop', 'art pop', 'new americana', 'alternative country', 'indie folk', 'countrygaze', 'indie rock', 'folk', 'modern folk rock'}

# %% [markdown]
# ### PCA
# - My scree plot indicated that 2 principal components accounted for .46 and .22 variance, whereas a 3rd component would account only for .1. Therefore I chose to use 2 principal components. These are also easier to visualize.
# - I then plotted the loadings to sanity check my findings. It is sound to me that acousticness and mode affect their respective components heavily. Energy, valence, and danciness all measure the happiness/liveliness of a track, so it is logical that they are grouped together.

# %% [markdown]
# ### Genres PCA

# %%
from sklearn.decomposition import PCA
import seaborn

# %%
pca = PCA(n_components=6)

genre_pc = pd.DataFrame(pca.fit_transform(gc))
genre_pc.set_index(gc_norm.index, inplace=True)
genre_pc.head()
# Out:
#                                 0         1         2         3         4  \
# name
# 849 find out            -3.046047 -0.286518 -1.113752 -0.241853 -0.937253
# 848 innocence           -3.633821  0.549147  1.019031  0.345694  1.802781
# 847 sick joke           -2.988313  0.051254 -1.362499 -0.017101 -1.346762
# 846 save me             -2.865709  0.537861  0.779059  0.687837  0.984393
# 845 what did you expect -3.474749  0.375979  1.038400 -0.849114  1.589680
#
#                                 5
# name
# 849 find out            -0.243304
# 848 innocence            0.827397
# 847 sick joke           -0.097005
# 846 save me              0.797590
# 845 what did you expect  1.898212

# %%
pc_vals = np.arange(pca.n_components_) + 1
plt.plot(pc_vals, pca.explained_variance_ratio_, 'o-', linewidth=2, color='blue')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %%
loadings = pca.components_
n_features = pca.n_features_in_
feature_names = gc.columns

pc_list = [f'PC{i}' for i in list(range(1, n_features + 1))]
pc_loadings = dict(zip(pc_list, loadings))

loadings_df = pd.DataFrame.from_dict(pc_loadings)
loadings_df['feature_names'] = feature_names
loadings_df = loadings_df.set_index('feature_names')
loadings_df
# Out:
#                           PC1       PC2       PC3       PC4       PC5  \
# feature_names
# indie pop            0.123676  0.384233 -0.284740  0.419078  0.129838
# modern indie folk   -0.003616  0.015239 -0.024308  0.004294 -0.026149
# hyperpop            -0.007726  0.004840  0.005792  0.006197  0.013178
# hypnagogic pop      -0.008687  0.004955  0.008857 -0.000499  0.013522
# art pop              0.174932  0.271284  0.188090  0.145209  0.435506
# ...                       ...       ...       ...       ...       ...
# classic girl group  -0.000653 -0.000359  0.000461 -0.001571  0.000688
# dalarna indie       -0.000305 -0.000181 -0.000020  0.000024 -0.000091
# swedish garage rock -0.000305 -0.000181 -0.000020  0.000024 -0.000091
# dmv rap             -0.000163  0.000206  0.000850  0.000298  0.001272
# malaysian pop       -0.000358 -0.000210 -0.000161 -0.000108  0.000025
#
#                           PC6
# feature_names
# indie pop           -0.013396
# modern indie folk   -0.002225
# hyperpop             0.012722
# hypnagogic pop       0.023014
# art pop              0.477191
# ...                       ...
# classic girl group  -0.000148
# dalarna indie       -0.000999
# swedish garage rock -0.000999
# dmv rap              0.001850
# malaysian pop       -0.000896
#
# [830 rows x 6 columns]

# %%
xs = loadings_df['PC1']
ys = loadings_df['PC2']

for i, varnames in enumerate(feature_names):
    plt.scatter(xs[i], ys[i], s=200)
    plt.text(xs[i], ys[i], varnames)

xticks = np.linspace(-0.8, 0.8, num=5)
yticks = np.linspace(-0.8, 0.8, num=5)
plt.xticks(xticks)
plt.yticks(yticks)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.title('2D Loading plot')

plt.show()
# Out:
# /var/folders/dy/m7tb4mx52sv0lxfvtf95srbc0000gn/T/ipykernel_25634/692851726.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.scatter(xs[i], ys[i], s=200)
# /var/folders/dy/m7tb4mx52sv0lxfvtf95srbc0000gn/T/ipykernel_25634/692851726.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(xs[i], ys[i], varnames)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=6)
kmeans.fit(loadings_df)

cluster_df = loadings_df.copy()
cluster_df['cluster'] = kmeans.labels_
cluster_df
# Out:
#                           PC1       PC2       PC3       PC4       PC5  \
# feature_names
# indie pop            0.123676  0.384233 -0.284740  0.419078  0.129838
# modern indie folk   -0.003616  0.015239 -0.024308  0.004294 -0.026149
# hyperpop            -0.007726  0.004840  0.005792  0.006197  0.013178
# hypnagogic pop      -0.008687  0.004955  0.008857 -0.000499  0.013522
# art pop              0.174932  0.271284  0.188090  0.145209  0.435506
# ...                       ...       ...       ...       ...       ...
# classic girl group  -0.000653 -0.000359  0.000461 -0.001571  0.000688
# dalarna indie       -0.000305 -0.000181 -0.000020  0.000024 -0.000091
# swedish garage rock -0.000305 -0.000181 -0.000020  0.000024 -0.000091
# dmv rap             -0.000163  0.000206  0.000850  0.000298  0.001272
# malaysian pop       -0.000358 -0.000210 -0.000161 -0.000108  0.000025
#
#                           PC6  cluster
# feature_names
# indie pop           -0.013396        2
# modern indie folk   -0.002225        0
# hyperpop             0.012722        0
# hypnagogic pop       0.023014        0
# art pop              0.477191        3
# ...                       ...      ...
# classic girl group  -0.000148        0
# dalarna indie       -0.000999        0
# swedish garage rock -0.000999        0
# dmv rap              0.001850        0
# malaysian pop       -0.000896        0
#
# [830 rows x 7 columns]

# %%
cluster_2 = cluster_df[cluster_df['cluster'] == 2].index.values
cluster_2
# Out:
# array(['indie pop'], dtype=object)

# %%
filtered_loadings = loadings_df.copy()
filtered_loadings.head()
# Out:
#                         PC1       PC2       PC3       PC4       PC5       PC6
# feature_names
# indie pop          0.123676  0.384233 -0.284740  0.419078  0.129838 -0.013396
# modern indie folk -0.003616  0.015239 -0.024308  0.004294 -0.026149 -0.002225
# hyperpop          -0.007726  0.004840  0.005792  0.006197  0.013178  0.012722
# hypnagogic pop    -0.008687  0.004955  0.008857 -0.000499  0.013522  0.023014
# art pop            0.174932  0.271284  0.188090  0.145209  0.435506  0.477191

# %%
filtered_loadings = filtered_loadings[abs(filtered_loadings) > 0.1]
filtered_loadings.fillna(0, inplace=True)
filtered_loadings = filtered_loadings.loc[(filtered_loadings != 0).any(axis=1)]
filtered_loadings.head()
# Out:
#                       PC1       PC2      PC3       PC4       PC5       PC6
# feature_names
# indie pop        0.123676  0.384233 -0.28474  0.419078  0.129838  0.000000
# art pop          0.174932  0.271284  0.18809  0.145209  0.435506  0.477191
# escape room      0.000000  0.000000  0.00000  0.000000  0.117546  0.000000
# alternative r&b -0.137030  0.000000  0.00000 -0.198248  0.172016  0.123868
# pop             -0.143696  0.000000  0.00000  0.236886  0.150947 -0.278826

# %%
xs = filtered_loadings['PC1']
ys = filtered_loadings['PC6']

for i, varnames in enumerate(filtered_loadings.index):
    plt.scatter(xs[i], ys[i], s=200)
    plt.text(xs[i], ys[i], varnames)

xticks = np.linspace(-0.8, 0.8, num=5)
yticks = np.linspace(-0.8, 0.8, num=5)
plt.xticks(xticks)
plt.yticks(yticks)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.axhline(0, color='black')
plt.axvline(0, color='black')
plt.title('2D Loading plot')
# Out:
# /var/folders/dy/m7tb4mx52sv0lxfvtf95srbc0000gn/T/ipykernel_25634/4152421268.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.scatter(xs[i], ys[i], s=200)
# /var/folders/dy/m7tb4mx52sv0lxfvtf95srbc0000gn/T/ipykernel_25634/4152421268.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(xs[i], ys[i], varnames)
# Text(0.5, 1.0, '2D Loading plot')

# %%
pc1 = 'pop rock'
pc2 = 'pop'
pc3 = 'rock'
pc4 = 'indie rock'
pc5 = ''
pc6 = 'rock'

# %% [markdown]
# ### Audio Features PCA

# %%
pca = PCA(n_components=2)

pc = pd.DataFrame(pca.fit_transform(playlist_features))
pc.set_index(gc.index, inplace=True)
pc.head()
# Out:
#                                 0         1
# name
# 849 find out            -0.055200  0.052618
# 848 innocence           -0.563099 -0.254309
# 847 sick joke            0.462457 -0.090733
# 846 save me             -0.258846  0.127597
# 845 what did you expect -0.428959 -0.817729

# %%
pc_vals = np.arange(pca.n_components_) + 1
plt.plot(pc_vals, pca.explained_variance_ratio_, 'o-', linewidth=2, color='blue')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Variance Explained')
plt.show()

# %%
loadings = pca.components_
n_features = pca.n_features_in_
feature_names = playlist_features.columns

pc_list = [f'PC{i}' for i in list(range(1, n_features + 1))]
pc_loadings = dict(zip(pc_list, loadings))

loadings_df = pd.DataFrame.from_dict(pc_loadings)
loadings_df['feature_names'] = feature_names
loadings_df = loadings_df.set_index('feature_names')
loadings_df
# Out:
#                        PC1       PC2
# feature_names
# danceability     -0.142922 -0.045507
# energy           -0.415771  0.165805
# key              -0.068275 -0.178232
# loudness         -0.319057  0.132912
# mode              0.346516  0.905756
# speechiness      -0.091282 -0.072726
# acousticness      0.705497 -0.300706
# instrumentalness  0.017765 -0.011404
# liveness         -0.076406  0.032002
# valence          -0.260285  0.047921
# tempo            -0.014675  0.038054

# %%
xs = loadings[0]
ys = loadings[1]

for i, varnames in enumerate(feature_names):
    plt.scatter(xs[i], ys[i], s=200)
    plt.text(xs[i], ys[i], varnames)

xticks = np.linspace(-0.8, 0.8, num=5)
yticks = np.linspace(-0.8, 0.8, num=5)
plt.xticks(xticks)
plt.yticks(yticks)
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('2D Loading plot')
plt.show()

# %% [markdown]
# ### Merging Genre and PC DataFrames

# %%
gc_norm = gc.copy()
for column in gc_norm.columns:
    gc_norm[column] = gc_norm[column] / gc_norm[column].abs().max()

gc_norm
# Out:
#                                    indie pop  modern indie folk  hyperpop  \
# name
# 849 find out                        0.111111                0.5      0.25
# 848 innocence                       0.000000                0.0      0.00
# 847 sick joke                       0.111111                0.0      0.00
# 846 save me                         0.000000                0.0      0.00
# 845 what did you expect             0.000000                0.0      0.00
# ...                                      ...                ...       ...
# 00 think about it                   0.333333                0.0      0.00
# 00 remember                         0.000000                0.0      0.00
# 00 remind me                        0.111111                0.0      0.00
# 00 forgetting                       0.111111                0.0      0.00
# 2022 releases i missed, whoopies!   0.222222                0.0      0.00
#
#                                    hypnagogic pop  art pop  escape room  \
# name
# 849 find out                                  0.5    0.000          0.0
# 848 innocence                                 0.5    0.375          0.4
# 847 sick joke                                 0.0    0.000          0.0
# 846 save me                                   0.5    0.375          0.0
# 845 what did you expect                       0.5    0.375          0.2
# ...                                           ...      ...          ...
# 00 think about it                             0.0    0.125          0.0
# 00 remember                                   0.0    0.000          0.0
# 00 remind me                                  0.0    0.250          0.0
# 00 forgetting                                 0.0    0.000          0.0
# 2022 releases i missed, whoopies!             0.0    0.500          0.0
#
#                                    alternative r&b       pop  \
# name
# 849 find out                              0.000000  0.000000
# 848 innocence                             0.285714  0.285714
# 847 sick joke                             0.000000  0.000000
# 846 save me                               0.000000  0.142857
# 845 what did you expect                   0.428571  0.000000
# ...                                            ...       ...
# 00 think about it                         0.000000  0.142857
# 00 remember                               0.000000  0.000000
# 00 remind me                              0.000000  0.000000
# 00 forgetting                             0.000000  0.000000
# 2022 releases i missed, whoopies!         0.142857  0.142857
#
#                                    social media pop  chillwave  ...  \
# name                                                            ...
# 849 find out                                    0.0       0.00  ...
# 848 innocence                                   1.0       0.25  ...
# 847 sick joke                                   0.0       0.00  ...
# 846 save me                                     0.0       0.25  ...
# 845 what did you expect                         0.0       0.25  ...
# ...                                             ...        ...  ...
# 00 think about it                               0.0       0.00  ...
# 00 remember                                     0.0       0.00  ...
# 00 remind me                                    0.0       0.00  ...
# 00 forgetting                                   0.0       0.00  ...
# 2022 releases i missed, whoopies!               0.0       0.00  ...
#
#                                    neo-singer-songwriter  japanese chillhop  \
# name
# 849 find out                                         0.0                0.0
# 848 innocence                                        0.0                0.0
# 847 sick joke                                        0.0                0.0
# 846 save me                                          0.0                0.0
# 845 what did you expect                              0.0                0.0
# ...                                                  ...                ...
# 00 think about it                                    0.0                0.0
# 00 remember                                          0.0                0.0
# 00 remind me                                         0.0                0.0
# 00 forgetting                                        0.0                0.0
# 2022 releases i missed, whoopies!                    0.0                0.0
#
#                                    indie emo  electronic trap  \
# name
# 849 find out                             0.0              0.0
# 848 innocence                            0.0              0.0
# 847 sick joke                            0.0              0.0
# 846 save me                              0.0              0.0
# 845 what did you expect                  0.0              0.0
# ...                                      ...              ...
# 00 think about it                        0.0              0.0
# 00 remember                              0.0              0.0
# 00 remind me                             0.0              0.0
# 00 forgetting                            0.0              0.0
# 2022 releases i missed, whoopies!        0.0              0.0
#
#                                    progressive electro house  \
# name
# 849 find out                                             0.0
# 848 innocence                                            0.0
# 847 sick joke                                            0.0
# 846 save me                                              0.0
# 845 what did you expect                                  0.0
# ...                                                      ...
# 00 think about it                                        0.0
# 00 remember                                              0.0
# 00 remind me                                             0.0
# 00 forgetting                                            0.0
# 2022 releases i missed, whoopies!                        0.0
#
#                                    classic girl group  dalarna indie  \
# name
# 849 find out                                      0.0            0.0
# 848 innocence                                     0.0            0.0
# 847 sick joke                                     0.0            0.0
# 846 save me                                       0.0            0.0
# 845 what did you expect                           0.0            0.0
# ...                                               ...            ...
# 00 think about it                                 0.0            0.0
# 00 remember                                       0.0            0.0
# 00 remind me                                      0.0            0.0
# 00 forgetting                                     0.0            0.0
# 2022 releases i missed, whoopies!                 0.0            0.0
#
#                                    swedish garage rock  dmv rap  malaysian pop
# name
# 849 find out                                       0.0      0.0            0.0
# 848 innocence                                      0.0      0.0            0.0
# 847 sick joke                                      0.0      0.0            0.0
# 846 save me                                        0.0      0.0            0.0
# 845 what did you expect                            0.0      0.0            0.0
# ...                                                ...      ...            ...
# 00 think about it                                  0.0      0.0            0.0
# 00 remember                                        0.0      0.0            0.0
# 00 remind me                                       0.0      0.0            0.0
# 00 forgetting                                      0.0      0.0            0.0
# 2022 releases i missed, whoopies!                  0.0      0.0            0.0
#
# [927 rows x 830 columns]

# %%
features = gc_norm.join(pc)
features.rename(columns={0: 'PC1', 1: 'PC2'}, inplace=True)
features = features.set_index(gc.index)
features
# Out:
#                                    indie pop  modern indie folk  hyperpop  \
# name
# 849 find out                        0.111111                0.5      0.25
# 848 innocence                       0.000000                0.0      0.00
# 847 sick joke                       0.111111                0.0      0.00
# 846 save me                         0.000000                0.0      0.00
# 845 what did you expect             0.000000                0.0      0.00
# ...                                      ...                ...       ...
# 00 think about it                   0.333333                0.0      0.00
# 00 remember                         0.000000                0.0      0.00
# 00 remind me                        0.111111                0.0      0.00
# 00 forgetting                       0.111111                0.0      0.00
# 2022 releases i missed, whoopies!   0.222222                0.0      0.00
#
#                                    hypnagogic pop  art pop  escape room  \
# name
# 849 find out                                  0.5    0.000          0.0
# 848 innocence                                 0.5    0.375          0.4
# 847 sick joke                                 0.0    0.000          0.0
# 846 save me                                   0.5    0.375          0.0
# 845 what did you expect                       0.5    0.375          0.2
# ...                                           ...      ...          ...
# 00 think about it                             0.0    0.125          0.0
# 00 remember                                   0.0    0.000          0.0
# 00 remind me                                  0.0    0.250          0.0
# 00 forgetting                                 0.0    0.000          0.0
# 2022 releases i missed, whoopies!             0.0    0.500          0.0
#
#                                    alternative r&b       pop  \
# name
# 849 find out                              0.000000  0.000000
# 848 innocence                             0.285714  0.285714
# 847 sick joke                             0.000000  0.000000
# 846 save me                               0.000000  0.142857
# 845 what did you expect                   0.428571  0.000000
# ...                                            ...       ...
# 00 think about it                         0.000000  0.142857
# 00 remember                               0.000000  0.000000
# 00 remind me                              0.000000  0.000000
# 00 forgetting                             0.000000  0.000000
# 2022 releases i missed, whoopies!         0.142857  0.142857
#
#                                    social media pop  chillwave  ...  \
# name                                                            ...
# 849 find out                                    0.0       0.00  ...
# 848 innocence                                   1.0       0.25  ...
# 847 sick joke                                   0.0       0.00  ...
# 846 save me                                     0.0       0.25  ...
# 845 what did you expect                         0.0       0.25  ...
# ...                                             ...        ...  ...
# 00 think about it                               0.0       0.00  ...
# 00 remember                                     0.0       0.00  ...
# 00 remind me                                    0.0       0.00  ...
# 00 forgetting                                   0.0       0.00  ...
# 2022 releases i missed, whoopies!               0.0       0.00  ...
#
#                                    indie emo  electronic trap  \
# name
# 849 find out                             0.0              0.0
# 848 innocence                            0.0              0.0
# 847 sick joke                            0.0              0.0
# 846 save me                              0.0              0.0
# 845 what did you expect                  0.0              0.0
# ...                                      ...              ...
# 00 think about it                        0.0              0.0
# 00 remember                              0.0              0.0
# 00 remind me                             0.0              0.0
# 00 forgetting                            0.0              0.0
# 2022 releases i missed, whoopies!        0.0              0.0
#
#                                    progressive electro house  \
# name
# 849 find out                                             0.0
# 848 innocence                                            0.0
# 847 sick joke                                            0.0
# 846 save me                                              0.0
# 845 what did you expect                                  0.0
# ...                                                      ...
# 00 think about it                                        0.0
# 00 remember                                              0.0
# 00 remind me                                             0.0
# 00 forgetting                                            0.0
# 2022 releases i missed, whoopies!                        0.0
#
#                                    classic girl group  dalarna indie  \
# name
# 849 find out                                      0.0            0.0
# 848 innocence                                     0.0            0.0
# 847 sick joke                                     0.0            0.0
# 846 save me                                       0.0            0.0
# 845 what did you expect                           0.0            0.0
# ...                                               ...            ...
# 00 think about it                                 0.0            0.0
# 00 remember                                       0.0            0.0
# 00 remind me                                      0.0            0.0
# 00 forgetting                                     0.0            0.0
# 2022 releases i missed, whoopies!                 0.0            0.0
#
#                                    swedish garage rock  dmv rap  \
# name
# 849 find out                                       0.0      0.0
# 848 innocence                                      0.0      0.0
# 847 sick joke                                      0.0      0.0
# 846 save me                                        0.0      0.0
# 845 what did you expect                            0.0      0.0
# ...                                                ...      ...
# 00 think about it                                  0.0      0.0
# 00 remember                                        0.0      0.0
# 00 remind me                                       0.0      0.0
# 00 forgetting                                      0.0      0.0
# 2022 releases i missed, whoopies!                  0.0      0.0
#
#                                    malaysian pop       PC1       PC2
# name
# 849 find out                                 0.0 -0.055200  0.052618
# 848 innocence                                0.0 -0.563099 -0.254309
# 847 sick joke                                0.0  0.462457 -0.090733
# 846 save me                                  0.0 -0.258846  0.127597
# 845 what did you expect                      0.0 -0.428959 -0.817729
# ...                                          ...       ...       ...
# 00 think about it                            0.0  0.125416  0.131133
# 00 remember                                  0.0  0.090718  0.023620
# 00 remind me                                 0.0  0.418437 -0.012456
# 00 forgetting                                0.0  0.367797 -0.030212
# 2022 releases i missed, whoopies!            0.0 -0.144381  0.144513
#
# [927 rows x 832 columns]

# %%
features.columns
# Out:
# Index(['indie pop', 'modern indie folk', 'hyperpop', 'hypnagogic pop',
#        'art pop', 'escape room', 'alternative r&b', 'pop', 'social media pop',
#        'chillwave',
#        ...
#        'indie emo', 'electronic trap', 'progressive electro house',
#        'classic girl group', 'dalarna indie', 'swedish garage rock', 'dmv rap',
#        'malaysian pop', 'PC1', 'PC2'],
#       dtype='object', length=832)

# %% [markdown]
# ### Clustering
# - I used k-medoids rather than k-means for this project because it is more resistant to outliers and actually finds an existing point as a centroid. This was useful to me because there would be no way to reverse engineer a centroid "playlist" of a k-means analysis.
# - Silhouette score analysis indicated that 4 clusters gave the most distinct groupings.

# %%
from sklearn_extra.cluster import KMedoids as kmedoids
from sklearn.metrics import silhouette_score

# %%
X = features.set_index(genres['name'])
X
# Out:
#                                    indie pop  modern indie folk  hyperpop  \
# name
# 849 find out                        0.111111                0.5      0.25
# 848 innocence                       0.000000                0.0      0.00
# 847 sick joke                       0.111111                0.0      0.00
# 846 save me                         0.000000                0.0      0.00
# 845 what did you expect             0.000000                0.0      0.00
# ...                                      ...                ...       ...
# 00 think about it                   0.333333                0.0      0.00
# 00 remember                         0.000000                0.0      0.00
# 00 remind me                        0.111111                0.0      0.00
# 00 forgetting                       0.111111                0.0      0.00
# 2022 releases i missed, whoopies!   0.222222                0.0      0.00
#
#                                    hypnagogic pop  art pop  escape room  \
# name
# 849 find out                                  0.5    0.000          0.0
# 848 innocence                                 0.5    0.375          0.4
# 847 sick joke                                 0.0    0.000          0.0
# 846 save me                                   0.5    0.375          0.0
# 845 what did you expect                       0.5    0.375          0.2
# ...                                           ...      ...          ...
# 00 think about it                             0.0    0.125          0.0
# 00 remember                                   0.0    0.000          0.0
# 00 remind me                                  0.0    0.250          0.0
# 00 forgetting                                 0.0    0.000          0.0
# 2022 releases i missed, whoopies!             0.0    0.500          0.0
#
#                                    alternative r&b       pop  \
# name
# 849 find out                              0.000000  0.000000
# 848 innocence                             0.285714  0.285714
# 847 sick joke                             0.000000  0.000000
# 846 save me                               0.000000  0.142857
# 845 what did you expect                   0.428571  0.000000
# ...                                            ...       ...
# 00 think about it                         0.000000  0.142857
# 00 remember                               0.000000  0.000000
# 00 remind me                              0.000000  0.000000
# 00 forgetting                             0.000000  0.000000
# 2022 releases i missed, whoopies!         0.142857  0.142857
#
#                                    social media pop  chillwave  ...  \
# name                                                            ...
# 849 find out                                    0.0       0.00  ...
# 848 innocence                                   1.0       0.25  ...
# 847 sick joke                                   0.0       0.00  ...
# 846 save me                                     0.0       0.25  ...
# 845 what did you expect                         0.0       0.25  ...
# ...                                             ...        ...  ...
# 00 think about it                               0.0       0.00  ...
# 00 remember                                     0.0       0.00  ...
# 00 remind me                                    0.0       0.00  ...
# 00 forgetting                                   0.0       0.00  ...
# 2022 releases i missed, whoopies!               0.0       0.00  ...
#
#                                    indie emo  electronic trap  \
# name
# 849 find out                             0.0              0.0
# 848 innocence                            0.0              0.0
# 847 sick joke                            0.0              0.0
# 846 save me                              0.0              0.0
# 845 what did you expect                  0.0              0.0
# ...                                      ...              ...
# 00 think about it                        0.0              0.0
# 00 remember                              0.0              0.0
# 00 remind me                             0.0              0.0
# 00 forgetting                            0.0              0.0
# 2022 releases i missed, whoopies!        0.0              0.0
#
#                                    progressive electro house  \
# name
# 849 find out                                             0.0
# 848 innocence                                            0.0
# 847 sick joke                                            0.0
# 846 save me                                              0.0
# 845 what did you expect                                  0.0
# ...                                                      ...
# 00 think about it                                        0.0
# 00 remember                                              0.0
# 00 remind me                                             0.0
# 00 forgetting                                            0.0
# 2022 releases i missed, whoopies!                        0.0
#
#                                    classic girl group  dalarna indie  \
# name
# 849 find out                                      0.0            0.0
# 848 innocence                                     0.0            0.0
# 847 sick joke                                     0.0            0.0
# 846 save me                                       0.0            0.0
# 845 what did you expect                           0.0            0.0
# ...                                               ...            ...
# 00 think about it                                 0.0            0.0
# 00 remember                                       0.0            0.0
# 00 remind me                                      0.0            0.0
# 00 forgetting                                     0.0            0.0
# 2022 releases i missed, whoopies!                 0.0            0.0
#
#                                    swedish garage rock  dmv rap  \
# name
# 849 find out                                       0.0      0.0
# 848 innocence                                      0.0      0.0
# 847 sick joke                                      0.0      0.0
# 846 save me                                        0.0      0.0
# 845 what did you expect                            0.0      0.0
# ...                                                ...      ...
# 00 think about it                                  0.0      0.0
# 00 remember                                        0.0      0.0
# 00 remind me                                       0.0      0.0
# 00 forgetting                                      0.0      0.0
# 2022 releases i missed, whoopies!                  0.0      0.0
#
#                                    malaysian pop       PC1       PC2
# name
# 849 find out                                 0.0 -0.055200  0.052618
# 848 innocence                                0.0 -0.563099 -0.254309
# 847 sick joke                                0.0  0.462457 -0.090733
# 846 save me                                  0.0 -0.258846  0.127597
# 845 what did you expect                      0.0 -0.428959 -0.817729
# ...                                          ...       ...       ...
# 00 think about it                            0.0  0.125416  0.131133
# 00 remember                                  0.0  0.090718  0.023620
# 00 remind me                                 0.0  0.418437 -0.012456
# 00 forgetting                                0.0  0.367797 -0.030212
# 2022 releases i missed, whoopies!            0.0 -0.144381  0.144513
#
# [927 rows x 832 columns]

# %%
s_scores = []

num_clusters = 1
low_score = -1
for i in range(2, 10):
    s = silhouette_score(X, kmedoids(n_clusters=i, random_state=42).fit_predict(X))
    s_scores.append(s)
    if s > low_score:
        low_score = s
        num_clusters = i

print(num_clusters)
print(s_scores)
# Out:
# 2
# [0.03146226068797136, -0.026298207909495337, -0.09218371947100933, -0.10512252400699676, -0.10203430727302923, -0.10118065340326429, -0.10148160750290805, -0.11527006121880416]

# %%
plt.plot(range(2, 10), s_scores, 'o-', linewidth=2, color='blue')
plt.xticks(range(2, 10))
plt.title('Silhouette Scores')
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.show()

# %%
km = kmedoids(n_clusters=4)
clusters = km.fit_predict(X)

clustered = X.copy().reset_index()
clustered['cluster'] = clusters

# %%
cluster0 = clustered.loc[clustered['cluster'] == 0]
cluster0
# Out:
#                                   name  indie pop  modern indie folk  \
# 2                        847 sick joke   0.111111                0.0
# 6                      842 begin again   0.222222                0.0
# 7                        841 stay true   0.222222                0.0
# 11                   837 no pretending   0.222222                0.0
# 13                  835 maybe tomorrow   0.000000                0.0
# ..                                 ...        ...                ...
# 922                  00 think about it   0.333333                0.0
# 923                        00 remember   0.000000                0.0
# 924                       00 remind me   0.111111                0.0
# 925                      00 forgetting   0.111111                0.0
# 926  2022 releases i missed, whoopies!   0.222222                0.0
#
#      hyperpop  hypnagogic pop  art pop  escape room  alternative r&b  \
# 2         0.0             0.0    0.000          0.0         0.000000
# 6         0.0             0.0    0.750          0.2         0.000000
# 7         0.0             0.0    0.250          0.0         0.142857
# 11        0.0             0.5    0.250          0.2         0.428571
# 13        0.0             0.0    0.250          0.0         0.000000
# ..        ...             ...      ...          ...              ...
# 922       0.0             0.0    0.125          0.0         0.000000
# 923       0.0             0.0    0.000          0.0         0.000000
# 924       0.0             0.0    0.250          0.0         0.000000
# 925       0.0             0.0    0.000          0.0         0.000000
# 926       0.0             0.0    0.500          0.0         0.142857
#
#           pop  social media pop  ...  electronic trap  \
# 2    0.000000               0.0  ...              0.0
# 6    0.000000               0.0  ...              0.0
# 7    0.000000               0.0  ...              0.0
# 11   0.142857               0.0  ...              0.0
# 13   0.571429               0.0  ...              0.0
# ..        ...               ...  ...              ...
# 922  0.142857               0.0  ...              0.0
# 923  0.000000               0.0  ...              0.0
# 924  0.000000               0.0  ...              0.0
# 925  0.000000               0.0  ...              0.0
# 926  0.142857               0.0  ...              0.0
#
#      progressive electro house  classic girl group  dalarna indie  \
# 2                          0.0                 0.0            0.0
# 6                          0.0                 0.0            0.0
# 7                          0.0                 0.0            0.0
# 11                         0.0                 0.0            0.0
# 13                         0.0                 0.0            0.0
# ..                         ...                 ...            ...
# 922                        0.0                 0.0            0.0
# 923                        0.0                 0.0            0.0
# 924                        0.0                 0.0            0.0
# 925                        0.0                 0.0            0.0
# 926                        0.0                 0.0            0.0
#
#      swedish garage rock  dmv rap  malaysian pop       PC1       PC2  cluster
# 2                    0.0      0.0            0.0  0.462457 -0.090733        0
# 6                    0.0      0.0            0.0  0.025555  0.105252        0
# 7                    0.0      0.0            0.0 -0.649658 -0.712944        0
# 11                   0.0      0.0            0.0  0.214245 -0.510144        0
# 13                   0.0      0.0            0.0  0.198422  0.011505        0
# ..                   ...      ...            ...       ...       ...      ...
# 922                  0.0      0.0            0.0  0.125416  0.131133        0
# 923                  0.0      0.0            0.0  0.090718  0.023620        0
# 924                  0.0      0.0            0.0  0.418437 -0.012456        0
# 925                  0.0      0.0            0.0  0.367797 -0.030212        0
# 926                  0.0      0.0            0.0 -0.144381  0.144513        0
#
# [427 rows x 834 columns]

# %% [markdown]
# ### Visualization
# - It seems like cluster 2 became a sort of catchall category, which I'd like to investigate further.
# - I'd also like to create animated visualizations for this section, allowing users to access playlists by clicking on their points on the graph.

# %%
import seaborn as sns

# %%
ax = sns.scatterplot(x='PC1', y='PC2', data=clustered, hue='cluster', palette='bright')
# ax = sns.scatterplot(x= km.cluster_centers_[:, 0], y = km.cluster_centers_[:, 1], hue=range(num_clusters), s=40, ec='black', legend=False, ax=ax)

plt.show()

# %% [markdown]
# ### Recommendation System
# - I checked the centers of the clusters and was surprised to find that the central points were not highly self-similar playlists, but rather ones that I would have trouble categorizing by genre.
# - The final three functions access the pc1 and pc2 scores of a playlist by name, find its cluster, and calculate its euclidean distance to every other point in the cluster. closest() returns the nearest playlist in the cluster as a title string and a url for access.

# %%
from scipy.spatial import distance_matrix
from sklearn.metrics.pairwise import euclidean_distances

# %%
playlists = pd.read_csv('csv_files/playlists.csv')
playlists.head()
# Out:
#                       name                                          track_ids  \
# 0             849 find out  ['6vca0aMELa1kc6mIs6w39c', '5jOCZRdWItMJKacbZo...
# 1            848 innocence  ['6MzofobZt2dm0Kf1hTThFz', '5HwHdYpk3QiOUhsfWK...
# 2            847 sick joke  ['4ztA5OPlOzUvbE0Cgh2gV9', '505HhtdgN8lynQcJQC...
# 3              846 save me  ['3vlAqZvq7IYKOoOKwHGAxd', '0LXxEKF7GjUbGYCeBO...
# 4  845 what did you expect  ['0rxQTgJzd0HCUk4QUxSkjK', '74OfKhcmck9KUHBPmC...
#
#                                          track_names                      id  \
# 0  ['toothache', 'Death Grip', 'The fish song', '...  5oKwX8pOYWofuTNMKx4okR
# 1  ['Diet Pepsi', 'Passionfruit', 'tears in the c...  5sMFgzDK1HTjG2bxIyi9jI
# 2  ['something will give', 'Ever Seen', 'Birdwatc...  3oldJCV4dggIdDCB8aFlFc
# 3  ['double dog', 'Weirdwordsworms', 'Infinite Lo...  3g39V9zZwlt9ZYn7JKTOCj
# 4  ['Even If It Hurts (feat. Blood Orange)', 'Dri...  0KgwFInw8xWYmtDQWayf2p
#
#                                                  url  \
# 0  https://open.spotify.com/playlist/5oKwX8pOYWof...
# 1  https://open.spotify.com/playlist/5sMFgzDK1HTj...
# 2  https://open.spotify.com/playlist/3oldJCV4dggI...
# 3  https://open.spotify.com/playlist/3g39V9zZwlt9...
# 4  https://open.spotify.com/playlist/0KgwFInw8xWY...
#
#                                                image  \
# 0  https://mosaic.scdn.co/640/ab67616d00001e02bd8...
# 1  https://mosaic.scdn.co/640/ab67616d00001e024e5...
# 2  https://mosaic.scdn.co/640/ab67616d00001e0254c...
# 3  https://image-cdn-ak.spotifycdn.com/image/ab67...
# 4  https://image-cdn-ak.spotifycdn.com/image/ab67...
#
#                                                 zipp
# 0  [('6vca0aMELa1kc6mIs6w39c', 'toothache'), ('5j...
# 1  [('6MzofobZt2dm0Kf1hTThFz', 'Diet Pepsi'), ('5...
# 2  [('4ztA5OPlOzUvbE0Cgh2gV9', 'something will gi...
# 3  [('3vlAqZvq7IYKOoOKwHGAxd', 'double dog'), ('0...
# 4  [('0rxQTgJzd0HCUk4QUxSkjK', 'Even If It Hurts ...

# %%
def get_centers(df, centers):
    m = distance_matrix(centers, np.asmatrix(df.to_numpy()))
    return [df.index[i] for i in np.argmin(m, axis=1)]

centers = np.array(km.cluster_centers_)
get_centers(X, centers)
# Out:
# ['847 sick joke',
#  '849 find out',
#  '739 this always happens',
#  '832 might as well']

# %%
def playlist_to_coords(playlist):
    pc1 = clustered.loc[clustered["name"] == playlist]['PC1'].item()
    pc2 = clustered.loc[clustered["name"] == playlist]['PC2'].item()
    coords = np.array([pc1, pc2])
    return coords

def get_cluster(playlist):
    n = clustered[clustered['name'] == playlist]['cluster'].item()
    return clustered[clustered['cluster'] == n]

def closest(playlist):
    cluster_points = get_cluster(playlist)[['PC1', 'PC2']]
    distances = euclidean_distances([playlist_to_coords(playlist)], cluster_points)[0]
    closest_index = np.argmin(distances)
    closest_name = clustered.iloc[closest_index]['name']
    closest_link = playlists.loc[np.where(playlists['name'] == closest_name)]['url'].item()
    return closest_name, closest_link

# %%
closest('00 alright')
# Out:
# ('473 losing sleep',
#  'https://open.spotify.com/playlist/4whh6813413D9BEFOMjaQ5')

# %%
gc.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 gc.head()
#
# NameError: name 'gc' is not defined
